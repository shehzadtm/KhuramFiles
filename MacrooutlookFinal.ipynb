# %% [markdown]
# <a href="https://colab.research.google.com/github/shehzadtm/KhuramFiles/blob/main/MacrooutlookFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %run /content/drive/MyDrive/Codesep/macro_outlook_colab.py
# Out:
# ...
# Created Macro_Outlook_September_2026.xlsx
